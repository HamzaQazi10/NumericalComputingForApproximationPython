# %%
#Hamza Arshad Qazi
#SP19-BCS-084

def cal(x):
    ans=((x**2)-x-2)
    return ans
ErrMax=0.0000001
k=0  #Iteration Counter
rootA=1#input 1
rootB=4#input 2
cond=0
funMidPrev=0  # To store Previous Approximation
errorCond=0
while(cond==0 and k<35):
    mid=(rootA+rootB)/2 #Formula 
    print("Root Point is "+str(mid))
    funA=cal(rootA)
    funB=cal(rootB)
    funMid=cal(mid)
    print("Function of A is "+str(funA))
    print("Function of B is "+str(funB))
    print("Function of Mid is "+str(funMid))
    if((funA*funMid)<0):
        rootB=mid
    elif((funB*funMid)<0):
        rootA=mid
    else:
        print("The Approximate root is "+str(mid))
        cond=1
    print("A is "+str(rootA))
    print("B is "+str(rootB))
    k=k+1
    print("Iteration is "+str(k))
    midCheck=(rootA+rootB)/2
    if(errorCond!=0):# Check for Previous Value if available or not
        print("Present Approximation"+str(funMid))
        print("Previous Approximation"+str(funMidPrev))
        RelativeApproximateError=(funMid-funMidPrev)/funMid
        print("Error is "+str(RelativeApproximateError*100)+str('%'))
    else:
        print("No Previous Approximation, So unable to Calculate Relative Approximate Error ")
    errorCond=1
    funMidPrev=funMid
    if(abs(cal(midCheck)) > ErrMax):
        cond=0
    else:
        cond=1
        break
    print("------------------------Next Iteration------------------------------")
print('Approximate Root based on given Conditions(Stoping Criteria) is at ' + str(mid))
print("------------------------------------------------------")
# Out:
# Root Point is 2.5
# Function of A is -2
# Function of B is 10
# Function of Mid is 1.75
# A is 1
# B is 2.5
# Iteration is 1
# No Previous Approximation, So unable to Calculate Relative Approximate Error
# ------------------------Next Iteration------------------------------
# Root Point is 1.75
# Function of A is -2
# Function of B is 1.75
# Function of Mid is -0.6875
# A is 1.75
# B is 2.5
# Iteration is 2
# Present Approximation-0.6875
# Previous Approximation1.75
# Error is 354.54545454545456%
# ------------------------Next Iteration------------------------------
# Root Point is 2.125
# Function of A is -0.6875
# Function of B is 1.75
# Function of Mid is 0.390625
# A is 1.75
# B is 2.125
# Iteration is 3
# Present Approximation0.390625
# Previous Approximation-0.6875
# Error is 276.0%
# ------------------------Next Iteration------------------------------
# Root Point is 1.9375
# Function of A is -0.6875
# Function of B is 0.390625
# Function of Mid is -0.18359375
# A is 1.9375
# B is 2.125
# Iteration is 4
# Present Approximation-0.18359375
# Previous Approximation0.390625
# Error is 312.7659574468085%
# ------------------------Next Iteration------------------------------
# Root Point is 2.03125
# Function of A is -0.18359375
# Function of B is 0.390625
# Function of Mid is 0.0947265625
# A is 1.9375
# B is 2.03125
# Iteration is 5
# Present Approximation0.0947265625
# Previous Approximation-0.18359375
# Error is 293.8144329896908%
# ------------------------Next Iteration------------------------------
# Root Point is 1.984375
# Function of A is -0.18359375
# Function of B is 0.0947265625
# Function of Mid is -0.046630859375
# A is 1.984375
# B is 2.03125
# Iteration is 6
# Present Approximation-0.046630859375
# Previous Approximation0.0947265625
# Error is 303.14136125654454%
# ------------------------Next Iteration------------------------------
# Root Point is 2.0078125
# Function of A is -0.046630859375
# Function of B is 0.0947265625
# Function of Mid is 0.02349853515625
# A is 1.984375
# B is 2.0078125
# Iteration is 7
# Present Approximation0.02349853515625
# Previous Approximation-0.046630859375
# Error is 298.44155844155847%
# ------------------------Next Iteration------------------------------
# Root Point is 1.99609375
# Function of A is -0.046630859375
# Function of B is 0.02349853515625
# Function of Mid is -0.0117034912109375
# A is 1.99609375
# B is 2.0078125
# Iteration is 8
# Present Approximation-0.0117034912109375
# Previous Approximation0.02349853515625
# Error is 300.78226857887876%
# ------------------------Next Iteration------------------------------
# Root Point is 2.001953125
# Function of A is -0.0117034912109375
# Function of B is 0.02349853515625
# Function of Mid is 0.005863189697265625
# A is 1.99609375
# B is 2.001953125
# Iteration is 9
# Present Approximation0.005863189697265625
# Previous Approximation-0.0117034912109375
# Error is 299.6096291476903%
# ------------------------Next Iteration------------------------------
# Root Point is 1.9990234375
# Function of A is -0.0117034912109375
# Function of B is 0.005863189697265625
# Function of Mid is -0.0029287338256835938
# A is 1.9990234375
# B is 2.001953125
# Iteration is 10
# Present Approximation-0.0029287338256835938
# Previous Approximation0.005863189697265625
# Error is 300.19537609899055%
# ------------------------Next Iteration------------------------------
# Root Point is 2.00048828125
# Function of A is -0.0029287338256835938
# Function of B is 0.005863189697265625
# Function of Mid is 0.0014650821685791016
# A is 1.9990234375
# B is 2.00048828125
# Iteration is 11
# Present Approximation0.0014650821685791016
# Previous Approximation-0.0029287338256835938
# Error is 299.90235964198536%
# ------------------------Next Iteration------------------------------
# Root Point is 1.999755859375
# Function of A is -0.0029287338256835938
# Function of B is 0.0014650821685791016
# Function of Mid is -0.0007323622703552246
# A is 1.999755859375
# B is 2.00048828125
# Iteration is 12
# Present Approximation-0.0007323622703552246
# Previous Approximation0.0014650821685791016
# Error is 300.0488320989664%
# ------------------------Next Iteration------------------------------
# Root Point is 2.0001220703125
# Function of A is -0.0007323622703552246
# Function of B is 0.0014650821685791016
# Function of Mid is 0.00036622583866119385
# A is 1.999755859375
# B is 2.0001220703125
# Iteration is 13
# Present Approximation0.00036622583866119385
# Previous Approximation-0.0007323622703552246
# Error is 299.9755869308703%
# ------------------------Next Iteration------------------------------
# Root Point is 1.99993896484375
# Function of A is -0.0007323622703552246
# Function of B is 0.00036622583866119385
# Function of Mid is -0.00018310174345970154
# A is 1.99993896484375
# B is 2.0001220703125
# Iteration is 14
# Present Approximation-0.00018310174345970154
# Previous Approximation0.00036622583866119385
# Error is 300.0122072796077%
# ------------------------Next Iteration------------------------------
# Root Point is 2.000030517578125
# Function of A is -0.00018310174345970154
# Function of B is 0.00036622583866119385
# Function of Mid is 9.155366569757462e-05
# A is 1.99993896484375
# B is 2.000030517578125
# Iteration is 15
# Present Approximation9.155366569757462e-05
# Previous Approximation-0.00018310174345970154
# Error is 299.9938965464625%
# ------------------------Next Iteration------------------------------
# Root Point is 1.9999847412109375
# Function of A is -0.00018310174345970154
# Function of B is 9.155366569757462e-05
# Function of Mid is -4.5776134356856346e-05
# A is 1.9999847412109375
# B is 2.000030517578125
# Iteration is 16
# Present Approximation-4.5776134356856346e-05
# Previous Approximation9.155366569757462e-05
# Error is 300.0030517733346%
# ------------------------Next Iteration------------------------------
# Root Point is 2.0000076293945312
# Function of A is -4.5776134356856346e-05
# Function of B is 9.155366569757462e-05
# Function of Mid is 2.2888241801410913e-05
# A is 1.9999847412109375
# B is 2.0000076293945312
# Iteration is 17
# Present Approximation2.2888241801410913e-05
# Previous Approximation-4.5776134356856346e-05
# Error is 299.9984741249742%
# ------------------------Next Iteration------------------------------
# Root Point is 1.9999961853027344
# Function of A is -4.5776134356856346e-05
# Function of B is 2.2888241801410913e-05
# Function of Mid is -1.1444077244959772e-05
# A is 1.9999961853027344
# B is 2.0000076293945312
# Iteration is 18
# Present Approximation-1.1444077244959772e-05
# Previous Approximation2.2888241801410913e-05
# Error is 300.0007629404232%
# ------------------------Next Iteration------------------------------
# Root Point is 2.000001907348633
# Function of A is -1.1444077244959772e-05
# Function of B is 2.2888241801410913e-05
# Function of Mid is 5.722049536416307e-06
# A is 1.9999961853027344
# B is 2.000001907348633
# Iteration is 19
# Present Approximation5.722049536416307e-06
# Previous Approximation-1.1444077244959772e-05
# Error is 299.99961853051593%
# ------------------------Next Iteration------------------------------
# Root Point is 1.9999990463256836
# Function of A is -1.1444077244959772e-05
# Function of B is 5.722049536416307e-06
# Function of Mid is -2.8610220397240482e-06
# A is 1.9999990463256836
# B is 2.000001907348633
# Iteration is 20
# Present Approximation-2.8610220397240482e-06
# Previous Approximation5.722049536416307e-06
# Error is 300.0001907349239%
# ------------------------Next Iteration------------------------------
# Root Point is 2.000000476837158
# Function of A is -2.8610220397240482e-06
# Function of B is 5.722049536416307e-06
# Function of Mid is 1.4305117019830504e-06
# A is 1.9999990463256836
# B is 2.000000476837158
# Iteration is 21
# Present Approximation1.4305117019830504e-06
# Previous Approximation-2.8610220397240482e-06
# Error is 299.9999046325835%
# ------------------------Next Iteration------------------------------
# Root Point is 1.999999761581421
# Function of A is -2.8610220397240482e-06
# Function of B is 1.4305117019830504e-06
# Function of Mid is -7.152556804612686e-07
# A is 1.999999761581421
# B is 2.000000476837158
# Iteration is 22
# Present Approximation-7.152556804612686e-07
# Previous Approximation1.4305117019830504e-06
# Error is 300.0000476837196%
# ------------------------Next Iteration------------------------------
# Root Point is 2.0000001192092896
# Function of A is -7.152556804612686e-07
# Function of B is 1.4305117019830504e-06
# Function of Mid is 3.5762788286319847e-07
# A is 1.999999761581421
# B is 2.0000001192092896
# Iteration is 23
# Present Approximation3.5762788286319847e-07
# Previous Approximation-7.152556804612686e-07
# Error is 299.999976158143%
# ------------------------Next Iteration------------------------------
# Root Point is 1.9999999403953552
# Function of A is -7.152556804612686e-07
# Function of B is 3.5762788286319847e-07
# Function of Mid is -1.788139307734582e-07
# A is 1.9999999403953552
# B is 2.0000001192092896
# Iteration is 24
# Present Approximation-1.788139307734582e-07
# Previous Approximation3.5762788286319847e-07
# Error is 300.0000119209292%
# Approximate Root based on given Conditions(Stoping Criteria) is at 1.9999999403953552
# ------------------------------------------------------

# %%
cal(7)
# Out:
# 23

# %%
2*0.25
# Out:
# 0.5
