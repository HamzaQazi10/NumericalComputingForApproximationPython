# %%
import math
print("hello world")
def cal(x):
    #ans=(x**4)+(3*(x**3))-(15*(x**2))-(2*x)+(9)
    #ans=((3*x)-(math.cos(x))-(1))
    #ans=((x**3)-(9*(x**2))+28.66)
    ans=((x**2)-x-2)
    return ans
cal(4)
k=0

rootA=1#input 1
rootB=4#input 2

cond=0
funMidPrev=0  # To store Previous Approximation
errorCond=0
while(cond==0 and k<25):
    funA=cal(rootA)
    funB=cal(rootB)
    mid=((rootA*funB)-(rootB*funA))/(funB-funA)
    print("Root Point is "+str(mid))
    funMid=cal(mid)
    print("Function of A is "+str(funA))
    print("Function of B is "+str(funB))
    print("Function of Mid is "+str(funMid))
    if((funA*funMid)<0):
        rootB=mid
    elif((funB*funMid)<0):
        rootA=mid
    else:
        print("The Approximate root is "+str(mid))
        cond=1
    print("A is "+str(rootA))
    print("B is "+str(rootB))
    k=k+1
    print("Number of Iteration is "+str(k))
    if(errorCond!=0):# Check for Previous Value if available or not
        print("Present Approximation"+str(funMid))
        print("Previous Approximation"+str(funMidPrev))
        RelativeApproximateError=(funMid-funMidPrev)/funMid
        print("Error is "+str(RelativeApproximateError))
    else:
        print("No Previous Approximation, So unable to Calculate Relative Approximate Error ")
    errorCond=1
    funMidPrev=funMid
    print("-----------------------Next Iteration-------------------------------")
print('Approximate Root based on given Conditions(Stoping Criteria) is at ' + str(mid))
print("------------------------------------------------------")
# Out:
# hello world
# Root Point is 1.5
# Function of A is -2
# Function of B is 10
# Function of Mid is -1.25
# A is 1.5
# B is 4
# Number of Iteration is 1
# No Previous Approximation, So unable to Calculate Relative Approximate Error
# -----------------------Next Iteration-------------------------------
# Root Point is 1.7777777777777777
# Function of A is -1.25
# Function of B is 10
# Function of Mid is -0.617283950617284
# A is 1.7777777777777777
# B is 4
# Number of Iteration is 2
# Present Approximation-0.617283950617284
# Previous Approximation-1.25
# Error is -1.0249999999999997
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9069767441860463
# Function of A is -0.617283950617284
# Function of B is 10
# Function of Mid is -0.2704164413196328
# A is 1.9069767441860463
# B is 4
# Number of Iteration is 3
# Present Approximation-0.2704164413196328
# Previous Approximation-0.617283950617284
# Error is -1.2827160493827112
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9620853080568719
# Function of A is -0.2704164413196328
# Function of B is 10
# Function of Mid is -0.11230655196424189
# A is 1.9620853080568719
# B is 4
# Number of Iteration is 4
# Present Approximation-0.11230655196424189
# Previous Approximation-0.2704164413196328
# Error is -1.4078420767982684
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9847182425978986
# Function of A is -0.11230655196424189
# Function of B is 10
# Function of Mid is -0.0456117400970073
# A is 1.9847182425978986
# B is 4
# Number of Iteration is 5
# Present Approximation-0.0456117400970073
# Previous Approximation-0.11230655196424189
# Error is -1.462229060443379
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9938685571948647
# Function of A is -0.0456117400970073
# Function of B is 10
# Function of Mid is -0.018356733824533178
# A is 1.9938685571948647
# B is 4
# Number of Iteration is 6
# Present Approximation-0.018356733824533178
# Previous Approximation-0.0456117400970073
# Error is -1.484741595808765
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9975444116180026
# Function of A is -0.018356733824533178
# Function of B is 10
# Function of Mid is -0.007360735231690674
# A is 1.9975444116180026
# B is 4
# Number of Iteration is 7
# Present Approximation-0.007360735231690674
# Previous Approximation-0.018356733824533178
# Error is -1.4938723166540053
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9990172820170287
# Function of A is -0.007360735231690674
# Function of B is 10
# Function of Mid is -0.002947188214279972
# A is 1.9990172820170287
# B is 4
# Number of Iteration is 8
# Present Approximation-0.002947188214279972
# Previous Approximation-0.007360735231690674
# Error is -1.4975450146094507
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9996068355328531
# Function of A is -0.002947188214279972
# Function of B is 10
# Function of Mid is -0.0011793388231424728
# A is 1.9996068355328531
# B is 4
# Number of Iteration is 9
# Present Approximation-0.0011793388231424728
# Previous Approximation-0.002947188214279972
# Error is -1.4990173785908938
# -----------------------Next Iteration-------------------------------
# Root Point is 1.999842721845905
# Function of A is -0.0011793388231424728
# Function of B is 10
# Function of Mid is -0.0004718097258673559
# A is 1.999842721845905
# B is 4
# Number of Iteration is 10
# Present Approximation-0.0004718097258673559
# Previous Approximation-0.0011793388231424728
# Error is -1.499606850991518
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999370867593864
# Function of A is -0.0004718097258673559
# Function of B is 10
# Function of Mid is -0.00018873576376510215
# A is 1.9999370867593864
# B is 4
# Number of Iteration is 11
# Present Approximation-0.00018873576376510215
# Previous Approximation-0.0004718097258673559
# Error is -1.4998427243209909
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999748343871047
# Function of A is -0.00018873576376510215
# Function of B is 10
# Function of Mid is -7.54962053779451e-05
# A is 1.9999748343871047
# B is 4
# Number of Iteration is 12
# Present Approximation-7.54962053779451e-05
# Previous Approximation-0.00018873576376510215
# Error is -1.4999370871723046
# -----------------------Next Iteration-------------------------------
# Root Point is 1.999989933704177
# Function of A is -7.54962053779451e-05
# Function of B is 10
# Function of Mid is -3.019878613819138e-05
# A is 1.999989933704177
# B is 4
# Number of Iteration is 13
# Present Approximation-3.019878613819138e-05
# Previous Approximation-7.54962053779451e-05
# Error is -1.4999748345006363
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999959734735644
# Function of A is -3.019878613819138e-05
# Function of B is 10
# Function of Mid is -1.2079563094014034e-05
# A is 1.9999959734735644
# B is 4
# Number of Iteration is 14
# Present Approximation-1.2079563094014034e-05
# Previous Approximation-3.019878613819138e-05
# Error is -1.499989933672041
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999983893881286
# Function of A is -1.2079563094014034e-05
# Function of B is 10
# Function of Mid is -4.831833020357834e-06
# A is 1.9999983893881286
# B is 4
# Number of Iteration is 15
# Present Approximation-4.831833020357834e-06
# Previous Approximation-1.2079563094014034e-05
# Error is -1.4999959731885457
# -----------------------Next Iteration-------------------------------
# Root Point is 1.999999355755044
# Function of A is -4.831833020357834e-06
# Function of B is 10
# Function of Mid is -1.932734452925189e-06
# A is 1.999999355755044
# B is 4
# Number of Iteration is 16
# Present Approximation-1.932734452925189e-06
# Previous Approximation-4.831833020357834e-06
# Error is -1.4999983898692688
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999997423019842
# Function of A is -1.932734452925189e-06
# Function of B is 10
# Function of Mid is -7.730939808325843e-07
# A is 1.9999997423019842
# B is 4
# Number of Iteration is 17
# Present Approximation-7.730939808325843e-07
# Previous Approximation-1.932734452925189e-06
# Error is -1.4999993543394667
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999998969207884
# Function of A is -7.730939808325843e-07
# Function of B is 10
# Function of Mid is -3.0923762417423006e-07
# A is 1.9999998969207884
# B is 4
# Number of Iteration is 18
# Present Approximation-3.0923762417423006e-07
# Previous Approximation-7.730939808325843e-07
# Error is -1.499999742583099
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999999587683144
# Function of A is -3.0923762417423006e-07
# Function of B is 10
# Function of Mid is -1.2369505508758039e-07
# A is 1.9999999587683144
# B is 4
# Number of Iteration is 19
# Present Approximation-1.2369505508758039e-07
# Previous Approximation-3.0923762417423006e-07
# Error is -1.4999998904990917
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999999835073252
# Function of A is -1.2369505508758039e-07
# Function of B is 10
# Function of Mid is -4.9478023900206836e-08
# A is 1.9999999835073252
# B is 4
# Number of Iteration is 20
# Present Approximation-4.9478023900206836e-08
# Previous Approximation-1.2369505508758039e-07
# Error is -1.4999999057574185
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999999934029302
# Function of A is -4.9478023900206836e-08
# Function of B is 10
# Function of Mid is -1.979120933803813e-08
# A is 1.9999999934029302
# B is 4
# Number of Iteration is 21
# Present Approximation-1.979120933803813e-08
# Previous Approximation-4.9478023900206836e-08
# Error is -1.5000000280483876
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999999973611722
# Function of A is -1.979120933803813e-08
# Function of B is 10
# Function of Mid is -7.916483468761726e-09
# A is 1.9999999973611722
# B is 4
# Number of Iteration is 22
# Present Approximation-7.916483468761726e-09
# Previous Approximation-1.979120933803813e-08
# Error is -1.500000084145166
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999999989444688
# Function of A is -7.916483468761726e-09
# Function of B is 10
# Function of Mid is -3.1665936539582162e-09
# A is 1.9999999989444688
# B is 4
# Number of Iteration is 23
# Present Approximation-3.1665936539582162e-09
# Previous Approximation-7.916483468761726e-09
# Error is -1.499999789637103
# -----------------------Next Iteration-------------------------------
# Root Point is 1.9999999995777877
# Function of A is -3.1665936539582162e-09
# Function of B is 10
# Function of Mid is -1.2666367954494717e-09
# A is 1.9999999995777877
# B is 4
# Number of Iteration is 24
# Present Approximation-1.2666367954494717e-09
# Previous Approximation-3.1665936539582162e-09
# Error is -1.5000013147687978
# -----------------------Next Iteration-------------------------------
# Root Point is 1.999999999831115
# Function of A is -1.2666367954494717e-09
# Function of B is 10
# Function of Mid is -5.066547181797887e-10
# A is 1.999999999831115
# B is 4
# Number of Iteration is 25
# Present Approximation-5.066547181797887e-10
# Previous Approximation-1.2666367954494717e-09
# Error is -1.5
# -----------------------Next Iteration-------------------------------
# Approximate Root based on given Conditions(Stoping Criteria) is at 1.999999999831115
# ------------------------------------------------------
