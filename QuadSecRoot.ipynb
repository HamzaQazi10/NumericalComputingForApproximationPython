# %%
#print("CHANGES REQUIRE")
import math
def cal(x):
    ans=((math.sin(x))-(5*x)+2)
    return ans

rootA=0
rootB=1
def QuadSecRoot(a,b):
    rootA=a
    rootB=b
    k=0
    cond=0
    while(cond==0 and k<55):
        mid=(rootA+rootB)/2
        mid1=(rootA+mid)/2
        mid2=(mid+rootB)/2
        print("Mid is "+str(mid))
        print("Mid of Root A and Mid is "+str(mid1))
        print("Mid of Mid and Root B is "+str(mid2))
        funA=cal(rootA)
        funB=cal(rootB)
        funMid=cal(mid)
        funMid1=cal(mid1)
        funMid2=cal(mid2)

    #     v='%.6f'%funA
    #     v=v+1
    #     print(str(v))
        print("----Functions of Points----")
        print("Function of A is "+str(funA))
        print("Function of Mid1 is "+str(funMid1))
        print("Function of Mid is "+str(funMid))
        print("Function of Mid2 is "+str(funMid2))
        print("Function of B is "+str(funB))
        print("----Functions of Points----")
        if((funA*funMid1)<0):
            rootBprev=rootB
            rootB=mid1
        elif((funMid1*funMid)<0):
            rootAprev=rootA
            rootA=mid1
            rootBprev=rootB
            rootB=mid
        elif((funMid*funMid2)<0):
            rootAprev=rootA
            rootA=mid
            rootBprev=rootB
            rootB=mid2
        elif((funMid2*funB)<0):
            rootAprev=rootA
            rootA=mid2
        else:
            print("The Approximate root is "+str(mid))
            cond=1
        midCheck=(rootA+rootB)/2
        print("Tolerance "+str(abs(cal(midCheck))))
        
        if(abs(cal(midCheck)) > 0.000001):
            cond=0
        else:
            cond=1

        k=k+1
        print("New Root A is "+str(rootA))
        print("New Root B is "+str(rootB))
        print("Iteration Number is: "+str(k))
        print("--------------------------Next Iteration-------------------------------")
    return midCheck
QuadSecRoot(rootA,rootB)


    #     funC=cal(rootA)
    #     funD=cal(rootB)
    #     check1='%.6f'%funC
    #     check2='%.6f'%funD
    #     print(check1)
    #     print(check2)
    #     if(check1==check2):
    #         print("NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN")
    
    
    #     if(rootA==rootB or (rootB==rootBprev and rootA==rootAprev)):
    #         print("Root Found")
    #         break
# Out:
# Mid is 0.5
# Mid of Root A and Mid is 0.25
# Mid of Mid and Root B is 0.75
# ----Functions of Points----
# Function of A is 2.0
# Function of Mid1 is 0.997403959254523
# Function of Mid is -0.020574461395796995
# Function of Mid2 is -1.068361239976666
# Function of B is -2.1585290151921033
# ----Functions of Points----
# Tolerance 0.49127252908604757
# New Root A is 0.25
# New Root B is 0.5
# Iteration Number is: 1
# --------------------------Next Iteration-------------------------------
# Mid is 0.375
# Mid of Root A and Mid is 0.3125
# Mid of Mid and Root B is 0.4375
# ----Functions of Points----
# Function of A is 0.997403959254523
# Function of Mid1 is 0.7449385145803809
# Function of Mid is 0.49127252908604757
# Function of Mid2 is 0.2361762572039381
# Function of B is -0.020574461395796995
# ----Functions of Points----
# Tolerance 0.10802147149168384
# New Root A is 0.4375
# New Root B is 0.5
# Iteration Number is: 2
# ...
